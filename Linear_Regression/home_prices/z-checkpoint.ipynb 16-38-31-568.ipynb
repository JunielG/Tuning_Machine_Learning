# %%
import pandas as pd

# %%
d = {'year':[2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]}

# %%
c = pd.DataFrame(d)
c
# Out:
#    year
# 0  2017
# 1  2018
# 2  2019
# 3  2020
# 4  2021
# 5  2022
# 6  2023
# 7  2024
# 8  2025

# %%
c.to_csv('year.csv', index=False)
