# %%
import pandas as pd

# %%
d = {'year':[1990, 2000, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]}

# %%
c = pd.DataFrame(d)
c
# Out:
#     year
# 0   1990
# 1   2000
# 2   2010
# 3   2011
# 4   2012
# 5   2013
# 6   2014
# 7   2015
# 8   2016
# 9   2017
# 10  2018
# 11  2019
# 12  2020
# 13  2021
# 14  2022
# 15  2023
# 16  2024
# 17  2025

# %%
c.to_csv('year_2.csv', index=False)
